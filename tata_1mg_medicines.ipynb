# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url="https://www.1mg.com/drugs-all-medicines?page=2&label=b"
page=requests.get(url)

soup=BeautifulSoup(page.content,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1, maximum-scale=2, width=device-width height=device-height, viewport-fit=cover" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <meta content="#FFF3E3" name="theme-color"/>
# <!-- Windows Phone -->
# <meta content="#FFF3E3" name="msapplication-navbutton-color"/>
# <!-- iOS Safari -->
# <meta content="#FFF3E3" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <script nonce="93a4724d20ce0572dd6e1e0b81bcd706">
#             dataLayer = []
#         </script>
# <!-- Partytown Integration Scripts -->
# <script nonce="93a4724d20ce0572dd6e1e0b81bcd706">
#             var googletag = googletag || {}
#             googletag.cmd = googletag.cmd || []
#         </script>
# <script nonce="93a4724d20ce0572dd6e1e0b81bcd706">
# ...

# %%
all_med=soup.find_all(class_="Card__container__liTc5 Card__productCard__SrdLF Card__direction__H8OmP container-fluid-padded-xl")
all_med
# Out:
# [<div class="Card__container__liTc5 Card__productCard__SrdLF Card__direction__H8OmP container-fluid-padded-xl"><a class="Card__productCard__SrdLF marginTop-4 Card__text__jeyhg" href="/drugs/brutaflam-mr-4-tablet-276118"><div class="Card__image__o88Qk col-2"><img alt="Brutaflam-MR 4 Tablet" src="https://onemg.gumlet.io/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/481e367c868d44d8b5e21066a6d5657e.jpg" title="Brutaflam-MR 4 Tablet"/></div><span class="Card__productCard__SrdLF Card__direction__H8OmP col-4"><p class="Card__productName__qw2CE bodyMedium">Brutaflam-MR 4 Tablet</p><p class="Card__productDescription__kL6Ho Card__flexAlignCenter____19g"><img alt="Rx" src="https://assets.1mg.com/pwa-app/production/mweb/2.0.0/static/images/svgs/icons/rx_icon.svg" title="Rx"/><span class="col-3">Prescription Required</span></p><p class="Card__productDescription__kL6Ho">strip of 10 tablets</p><p class="Card__productDescription__kL6Ho">Mankind Pharma Ltd</p><p class="Card__productDescription__kL6Ho">Et
# ...

# %%
first=[m.get_text() for m in all_med[0].find_all('p')]
first
# Out:
# ['Brutaflam-MR 4 Tablet',
#  'Prescription Required',
#  'strip of 10 tablets',
#  'Mankind Pharma Ltd',
#  'Etoricoxib (60mg) + Thiocolchicoside (4mg)']

# %%
prices=[p.get_text() for p in soup.find_all(class_="Price__price__Z7syt Price__align__dIdIz")]
prices
# Out:
# ['₹218.9',
#  '₹9.74',
#  '₹228',
#  '₹139',
#  '₹490.56',
#  '₹179',
#  '₹145.14',
#  '₹393.95',
#  '₹20.04',
#  '₹181.45',
#  '₹177',
#  '₹123',
#  '₹179.68',
#  '₹20',
#  '₹247.5',
#  '₹168',
#  '₹241.61',
#  '₹182',
#  '₹122',
#  '₹165',
#  '₹25.7',
#  '₹163',
#  '₹24',
#  '₹126.5',
#  '₹144',
#  '₹107.9',
#  '₹26.32',
#  '₹7117.5',
#  '₹1399',
#  '₹90.14']

# %%
len(first)
# Out:
# 5

# %%
#m.get_text() for m in all_med[0].find_all('p')
names, presc, pack, comp, cure =[],[],[],[],[]
for m in all_med:
    meds=[m1.get_text() for m1 in m.find_all('p')]
    if len(meds)==5:
        names.append(meds[0])
        presc.append(meds[1])
        pack.append(meds[2])
        comp.append(meds[3])
        cure.append(meds[4])
    else:
        names.append(meds[0])
        presc.append('Prescription Not Required')
        pack.append(meds[1])
        comp.append(meds[2])
        cure.append(meds[3])        
        
len(names), len(presc), len(pack), len(comp), len(cure)
# Out:
# (30, 30, 30, 30, 30)

# %% [markdown]
# ### Lets consider 100 pages for a each character/label

# %%
names, presc, pack, comp, cure,prices =[],[],[],[],[],[]

s="abcdefghijklmnopqrstuvwxyz"
for i in s:
    for pg in range(1,101):
        url=f"https://www.1mg.com/drugs-all-medicines?page={pg}&label={i}"
        page=requests.get(url)
        soup=BeautifulSoup(page.content,'lxml')
        all_med=soup.find_all(class_="Card__container__liTc5 Card__productCard__SrdLF Card__direction__H8OmP container-fluid-padded-xl")
        prices1=[p.get_text() for p in soup.find_all(class_="Price__price__Z7syt Price__align__dIdIz")]
        prices.extend(prices1)
        for m in all_med:
            meds=[m1.get_text() for m1 in m.find_all('p')]
            if len(meds)==5:
                names.append(meds[0])
                presc.append(meds[1])
                pack.append(meds[2])
                comp.append(meds[3])
                cure.append(meds[4])
            else:
                names.append(meds[0])
                presc.append('Prescription Not Required')
                pack.append(meds[1])
                comp.append(meds[2])
                cure.append(meds[3])

# %%
len(names), len(presc), len(pack), len(comp), len(cure)
